# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install accelerate -U
# !pip install transformers[torch]
# !pip install datasets
# Out:
# Collecting accelerate
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.30.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.2.1+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.30.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 28.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 45.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed datasets-2.19.1 dill-0.3.8 huggingface-hub-0.23.0 multiprocess-0.70.16 xxhash-3.4.1

# %%
model_name1 = "./drive/MyDrive/mT5_albert_100k/model"
model_name2 = "./drive/MyDrive/mT5_albert_200k"

# %%
from transformers import AutoTokenizer, MT5ForConditionalGeneration
from transformers import DataCollatorForSeq2Seq
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import MT5ForConditionalGeneration

# %%
model_100k = MT5ForConditionalGeneration.from_pretrained(model_name1)
model_200k = MT5ForConditionalGeneration.from_pretrained(model_name2)

# %%
def translate_text(text, model, tokenizer):
    inputs = tokenizer.encode("translate English to French: " + text, return_tensors="pt")
    outputs = model.generate(inputs, max_length=64, num_beams=4, early_stopping=True)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return translated_text

# %%
tokenizer = AutoTokenizer.from_pretrained("google/mt5-small")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
import pandas as pd


file_path = '/content/drive/My Drive/ColabNotebooks/filtered_en-fr.csv'

header = pd.read_csv(file_path, nrows=0).columns.tolist()
test_df = pd.read_csv(file_path, skiprows=200000, nrows=200, header=None, names=header)

print(tabulate(test_df, headers='keys', tablefmt='psql'))
# Out:
# +-----+------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------+
# |     | en                                                                                                   | fr                                                                                                   |
# |-----+------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------|
# |   0 | 15.5.2006 — Case C-410/05 — Commission v Greece.                                                     | 7.3.2006 — Affaire C-323/05 — Commission/Royaume-Uni.                                                |
# |   1 | DND Photo Another LAV III protective detachment.                                                     | photo du MDN Un autre détachement de protection de LAV III.                                          |
# |   2 | Landborder Conference Date(s): 2005-06-13 to 2005-06-15 Destination(s):                              | Conférence sur la frontière terrestre Date(s) : 2005-06-13 à 2005-06-15 Destination(s) :             |
# |   3 | • Recognize behaviour change as necessary throughout all themes.                                     | • Le changement de comportement doit être reconnu comme une nécessité dans tous les thèmes.          |
# |   4 | Some fishers also hold licences to fish herring for bait.                                            | Certains pêcheurs détiennent aussi des permis de pêche du hareng d'appât.                            |
# |   5 | If symptoms occur, get medical assistance immediately.                                               | En cas de symptômes, obtenez tout de suite une assistance médicale.                                  |
# |   6 | Each of these organizations has 15 member states.                                                    | Chacune de ces deux organisations compte 15 États membres.                                           |
# |   7 | In 2005 growth is forecast to rise to 3.3 per cent.                                                  | En 2005, le taux de croissance devrait atteindre 3,3 %.                                              |
# |   8 | Ibid., PCB Sept 73, Letellier to ADM(Per) Milroy, 13 August 1973.                                    | 73, Letellier au SMA(Per) Milroy, le 13 août 1973.                                                   |
# |   9 | Peter Mandelson was made EU Commissioner for Trade in 2004.                                          | Peter Mandelson a été nommé Commissaire au commerce de l'UE en 2004.                                 |
# |  10 | The documents listed below are country-specific.                                                     | • Manuels, sources et méthodes,(2)                                                                   |
# |  11 | School Networking in Angola All Basic Detail                                                         | School Networking in Angola Toute l'information Données générales Précisions                         |
# |  12 | It noted that it was true that the PCIPD already had a mandate which included certain aspects.       | Le PCIPD a par ailleurs déjà vu son mandat s’étendre à certains aspects.                             |
# |  13 | I have persisted in using the term >utilitarian= for two reasons.                                    | Si j’ai conservé celle d’« utilitariste » c’est pour deux raisons.                                   |
# |  14 | The provisions of this Article are not restricted by Article 1.                                      | Les dispositions du présent article ne sont pas restreintes par l’article 1.                         |
# |  15 | Natural gas prices declined for a 10th consecutive month in April on a year-over-year basis.         | En avril, le prix du gaz naturel d'une année à l'autre a reculé pour un dixième mois consécutif.     |
# |  16 | • Self-serve and PWGSC in collaboration with employer                                                | • Libre-service et TPSGC en collaboration avec l'employeur                                           |
# |  17 | Tuesday, 27 June 2006 Opened: 10.10 a.m. Suspended: 11.40 a.m. Resumed: 12 noon Closed: 1.05 p.m. 2. | Mardi 27 juin 2006 Ouverture : 10 h 10 Suspension : 11 h 40 Reprise : midi Clôture : 13 h 05 2.      |
# |  18 | • High energy prices represent an increased cost component which impacts on the steel industry.      | • Les prix élevés de l’énergie sont un élément d’augmentation des coûts dans cette industrie.        |
# |  19 | Orders the Commission to pay the costs.‘                                                             | 4) La Commission des Communautés européennes est condamnée aux dépens.»                              |
# |  20 | The subject field naming components are encoded as PrintableString.                                  | Les composantes d'attribution de nom du champ sont encodées en tant que PrintableString.             |
# |  21 | Nitrous oxide - Environmental aspects - Canada.                                                      | Oxyde azoteux - Aspect de l'environnement - Canada.                                                  |
# |  22 | PROTEGRA TECHNOLOGY GROUP Reference Number:                                                          | PROTEGRA TECHNOLOGY GROUP Numéro de référence:                                                       |
# |  23 | APWSS believes the proposal would:                                                                   | L'APWSS croit que le projet proposé :                                                                |
# |  24 | Canada Public Service School, 373 Sussex Drive, John Tait Room, D2 Block, Ottawa Total: $45.00       | École de la fonction publique du Canada, 373 Sussex, salle John Tait, Bloc D2, Ottawa Total : 45 $   |
# |  25 | • Current functional community pools                                                                 | • Les bassins actuels de collectivités fonctionnelles                                                |
# |  26 | This study is scheduled for completion during FY 2003-04. Status as of Jan 2003                      | Le comité directeur de ce projet a entrepris Situation en date du Janvier 2003                       |
# |  27 | ◦ Mirror your Web site in other locations.                                                           | ◦ Créez des sites miroirs de votre site Web dans d’autres emplacements.                              |
# |  28 | Audit subsidy payments total $1,296,637.                                                             | Les subventions de vérification se chiffrent à 1 296 637 $.                                          |
# |  29 | There was no abuse of authority in the decision to appoint Ms. McGuiness.                            | Il n’y a eu aucun abus de pouvoir dans la décision de nommer Mme McGuiness.                          |
# |  30 | • Assess the contracts governing consumers' use of these cards.                                      | • Évaluer les contrats régissant l'utilisation de ces cartes par les consommateurs.                  |
# |  31 | When members of the Olympic family cross the external borders of the Member States:                  | Lors du franchissement des frontières extérieures des États membres :                                |
# |  32 | S-9 Ships Crews Food and Catering Regulations, C.R.C. 1978, c.                                       | 27 Loi sur la marine marchande du Canada, L.R.C. (1985), ch.                                         |
# |  33 | • How did West Nile virus get to North America?                                                      | • Comment le virus du Nil occidental est-il arrivé en Amérique du Nord?                              |
# |  34 | (See paragraph 11 of document SCIT/SDWG/2/14.)                                                       | IV.                                                                                                  |
# |  35 | You wonder why this problem has developed.                                                           | Vous vous demandez ce qui s'est passé.                                                               |
# |  36 | Changes in the value of stocks could be due to the following factors.                                | Les variations de la valeur des encours pourraient être dues aux facteurs suivants.                  |
# |  37 | A model is given in Annex UA.IV.                                                                     | Un modèle est reproduit à l’annexe UA.IV.                                                            |
# |  38 | As well, the loss of positions reduced INAC's ability to input data and to monitor.                  | De plus, la perte d'effectifs a réduit la capacité d'AINC de saisir et de surveiller les données.    |
# |  39 | The Oﬃce will carry out other tasks assigned to it by the Council.                                   | Le Bureau exécutera les autres tâches que le Conseil lui assignera.                                  |
# |  40 | Negotiate federal-provincial-territorial income tax collection agreements.                           | Négocier les accords de perception fiscale fédéraux, provinciaux et territoriaux.                    |
# |  41 | It has 1462 residents, 1190 of which are permanent residents.                                        | Elle compte 1 462 membres dont 1 190 sont résidants permanents.                                      |
# |  42 | • Gagnon, Jacques C., Director of Communications, Minister's Office (as of 2007-03-12)               | • Gagnon, Jacques C., Directeur des communications, Cabinet du Ministre (à partir 2007-03-12)        |
# |  43 | Between 1997 and 1999, the Canada-Québec Labour Market Agreement was negotiated and signed.          | Entre 1997 et 1999, l’Entente Canada-Québec sur le marché du travail a été négociée et conclue.      |
# |  44 | Legislative resolution: 46 in favour, 0 against, 4 abstentions.                                      | Résolution législative: 46 voix pour, 0 contre et 4 abstentions.                                     |
# |  45 | WEU is called upon to play a major role in the field of armaments.                                   | L’UEO est appelée à jouer un grand rôle dans le domaine de l’armement.                               |
# |  46 | • Inspection of Biologics Manufacturers                                                              | • L'air dans les bureaux :                                                                           |
# |  47 | The Speaker is responsible for the Administration’s overall direction and management.                | Le Président veille à l’orientation et à la gestion générale de l’Administration.                    |
# |  48 | GROWTH OPPORTUNITIES FOR THE RECORDING INDUSTRY IN 2005                                              | OPPORTUNITÉS DE CROISSANCE DANS L'INDUSTRIE PHONOGRAPHIQUE EN 2005                                   |
# |  49 | • The Coordinator for Aboriginal Traditional Knowledge, in the COSEWIC Secretariat                   | • du coordonnateur des connaissances traditionnelles autochtones auSecrétariat du COSEPAC.           |
# |  50 | RIGHT TO APPEAL An appeal shall lie from the present decision.                                       | Par conséquent, l’Office a dû se prononcer sur la base des preuves dont il disposait.                |
# |  51 | • 1996-R-393 — Approval of plan and profile showing modification, wye-track at m.                    | • 1996-R-393 — Approbation plan et profil montrant modification, triangle de virage au p. m.         |
# |  52 | 4.6.4 TRANSACTIONS IN KIND                                                                           | 4.6.4 TRANSACTIONS NON FINANCIÈRES                                                                   |
# |  53 | For me there is no doubt, if the Council of Europe did not exist, we would have to invent it.        | Pour moi, il n’y a pas de doute, si le Conseil de l’Europe n’existait pas, il faudrait l’inventer.   |
# |  54 | Gonzague Langlois Tailings Pond 100 12 0                                                             | Gonzague Langlois Dépôt de résidus miniers 100 12 0                                                  |
# |  55 | • Priorities of the single market 2005-2010 – Rapporteur:                                            | • Les priorités du Marché unique 2005-2010 – Rapporteur:                                             |
# |  56 | Ms W. Reid Second Secretary (Immigration)                                                            | Mme W. Reid Deuxième secrétaire (Immigration)                                                        |
# |  57 | • Federal Partners in Technology Transfer Award Winners                                              | • Programme fédéral Partenaires en transfert de technologie - Récipiendaires des prix                |
# |  58 | Is this letter my study permit?                                                                      | Cette lettre constitue t elle mon permis?                                                            |
# |  59 | • Department of Health — Province of New Brunswick                                                   | • Ministère de la Santé — Province du Nouveau-Brunswick                                              |
# |  60 | March 1, 1999 Limit of Holdings:                                                                     | Le 1er mars 2000 Limite d’achat :                                                                    |
# |  61 | 1998/09/18 - FNACQ - "Hard Copy Document"DESCRIPTION:                                                | 1998/09/18 - FNACQ - "version imprimée"DESCRIPTION:                                                  |
# |  62 | Over the last year, a range of studies has been carried out in Canada's national parks.              | L'an dernier, toute une gamme d'études ont eu lieu dans les parcs nationaux du Canada.               |
# |  63 | Areas of Leadership                                                                                  | Secteurs de leadership                                                                               |
# |  64 | We haven't got it off the ground, we're just looking at it.                                          | Elle n'est pas terminée puisqu'elle est encore à l'étape de la conception.                           |
# |  65 | Part of this will be recognition of local commitment towardsconservation and stewardship.            | Il y a de nombreux exemples :                                                                        |
# |  66 | European Court of Human Rights Text adopted on 23 November 2004.                                     | Cour européenne des Droits de l’Homme Mise en œuvre des décisions de la Cour Résolution 1411 (2004)  |
# |  67 | CANADIAN PARI-MUTUEL AGENCY OBJECTIVE:                                                               | AGENCE CANADIENNE DU PARI MUTUEL OBJECTIF DU SECTEUR D’ACTIVITÉ :                                    |
# |  68 | EC Library, Downsview Contact Us                                                                     | Bibliothèque d'EC à Downsview Communiquez avec la bibliothèque                                       |
# |  69 | • For general enquiries:                                                                             | • Pour des renseignements généraux :                                                                 |
# |  70 | • A multi-disciplinary team or committee guiding the intiative;                                      | • une équipe multidisciplinaire ou un comité qui dirige l'initiative;                                |
# |  71 | The main lesson to be learned from the past concerns the internal organisation of the programme.     | Les principales leçons à retenir du passé concernent l’organisation interne du programme.            |
# |  72 | • Technical Manual on Paralympic Games                                                               | • Manuel technique sur la gestion des Jeux                                                           |
# |  73 | Canada argues that "some" and "significant" are not synonyms.                                        | Le Canada fait valoir que les termes "un certain" et "notable" ne sont pas synonymes.                |
# |  74 | (iii) Light Output Homogeneity.                                                                      | (iii) Homogénéité de l’émission lumineuse.                                                           |
# |  75 | Therefore: „Better Regulation instead of Deregulation".                                              | D’où « meilleure régulation à la place de dérégulation ».                                            |
# |  76 | Of the desirability [of legal protection for privacy] there can, it is believed, be no doubt.        | «Quant à la nécessité [d'une protection légale de la vie privée], il ne peut y avoir aucun doute.    |
# |  77 | PCT/R/WG/1/5 Annex III, page 4 [Rule 17.1, continued]                                                | PCT/R/WG/1/5 Annexe III, page 4 [Règle 17.1, suite]                                                  |
# |  78 | Its implementation is a priority for the Government of Canada.                                       | On trouvera davantage de renseignements sur le CRG en ligne61.                                       |
# |  79 | The maximum grant may not exceed EUR 100 000 per project.                                            | L’aide financière de l'Agence ne peut excéder 80% du total des frais éligibles du projet.            |
# |  80 | 11509) had been printed, and signed by 24 members of the Assembly.                                   | 11509), a été signée par 24 membres de l'Assemblée.                                                  |
# |  81 | CSA                                                                                                  | CA                                                                                                   |
# |  82 | Changing Structure of Business Organizations                                                         | Cohérence des données                                                                                |
# |  83 | Interculturality should not become a new religion".                                                  | L'interculturalité ne doit pas devenir une nouvelle religion ».                                      |
# |  84 | respondent found the office, and whether the services were available and provided in French.         | Le taux de réponse se situe à près de 15 pour cent, c e qui représente 450 répondants.               |
# |  85 | Documents on C.M.H.Q. file 9/5 Armd Diva' 1.                                                         | Ibid Annuaire du Canada de 1942, 746 (va.). Copie au dossier C.M.H.Q. 1/Co-Op/1/2.                   |
# |  86 | What can mayors and local elected representatives do about this problem?                             | Quel peut être le rôle des maires et des élus locaux face à ce problème ?                            |
# |  87 | Acceptance of the on-line dispute resolution system.                                                 | Acceptation du système de règlement en ligne des litiges 3.                                          |
# |  88 | • Define Min/Max Perf Metrics                                                                        | • Définition des paramètres de performance minimal/maximal                                           |
# |  89 | Survey on Tax Principles Canadian Federation of Independent Business, 1999 9.                        | Stepping-Up to Client-Centric Electronic Service Delivery                                            |
# |  90 | What types of complaints can be filed with the Agency?                                               | Quels types de plaintes peuvent être déposées auprès de l’Office?                                    |
# |  91 | Not denying the male concerns; 3.                                                                    | Ne pas nier les préoccupations masculines; 3.                                                        |
# |  92 | The goal will be to construct a short list of preferred strategies for each research priority.       | • Les PSN sont autant utilisés pour la promotion de la santé que pour le traitement des maladies.    |
# |  93 | As always, she stood firm and refused.                                                               | Comme toujours, elle a tenu tête à ces gens et a refusé de se désister.                              |
# |  94 | There is conclusive evidence that documents that are translated are more difficult than others.      | L'évidence prouve donc que les documents traduits sont plus difficiles à lire que les autres.        |
# |  95 | Success Factors and Implementation Issues Sengstack, Patricia P. and Gugerty, Brian.                 | Success Factors and Implementation Issues Sengstack, Patricia P. et Gugerty, Brian.                  |
# |  96 | Rapport d’activité (The Fight Against Racism and Discrimination), Paris:                             | Commissie Gelijke Behandeling – CGB / Commission pour l’égalité de traitement, Pays-Bas.             |
# |  97 | • never                                                                                              | • Jamais                                                                                             |
# |  98 | Ronald Bryden and Boyd Neil, eds, Whittaker's Theatre:                                               | Ronald Bryden et Boyd Neil, éd., « Whittaker's Theatre :                                             |
# |  99 | These challenges have had a significant effect on the industry.                                      | Ces défis ont eu un effet considérable sur l'industrie.                                              |
# | 100 | • 3-8-3 Appendix III - Reciprocal Transfer Agreements Cancelled                                      | • 3-8-3 Appendice III - Accords réciproques de transfert annulés                                     |
# | 101 | Adults in general Women Children 5-11 Children 1-4                                                   | Adultes en général Femmes Enfants 5 à 11 ans Enfants 1 à 4 ans                                       |
# | 102 | Look at your one–year and multiple–year subscription prices.                                         | Examinez aussi le prix de vos abonnements annuels et pluriannuels.                                   |
# | 103 | Ottawa, OntarioOctober 13 , 2006 CHECK AGAINST DELIVERY Thank you.                                   | Ottawa (Ontario)Le 13 octobre 2006 Merci!                                                            |
# | 104 | Kitimat is located at the head of Douglas Channel, 110 km east of Prince Rupert.                     | Kitimat est située à la tête du canal Douglas, à 110 km à l'est de Prince Rupert.                    |
# | 105 | • need to stop underenrolling women in clinical trials;276                                           | • la nécessité de cesser de recruter en nombre insuffisant les femmes pour les essais cliniques277;  |
# | 106 | • Better program planning and development;                                                           | • Amélioration de la planification et du développement de programmes                                 |
# | 107 | • Ultra-high precision electronic controls;                                                          | • commandes électroniques ultra-haute précision;                                                     |
# | 108 | Fishes of the North-eastern Atlantic and the Mediterranean, Unesco, Paris, vol.                      | Poissons de l'Atlantique Nord-Est et de la Méditerranée, Unesco, Paris, vol.                         |
# | 109 | E-mail correspondence between the artist and ITC (December 2002-January 2003).                       | Courriers électroniques entre l’artiste et le CCI (décembre 2002-janvier 2003).                      |
# | 110 | • 1,065 opening balance sheets of new registered electoral district associations                     | • 1 065 bilans d'ouverture de nouvelles associations de circonscription enregistrées;                |
# | 111 | Regrettably, as time passed, that was what happened.                                                 | Chance possible:                                                                                     |
# | 112 | CC-130 Hercules AUP Glass Cockpit.                                                                   | Poste de pilotage à écrans cathodiques PMA du CC-130 Hercules.                                       |
# | 113 | The appellant received a score of 5/20.                                                              | L’appelante a obtenu la note de 5 sur 20.                                                            |
# | 114 | First, the Committee on Ethics did not want to "reinvent the wheel".                                 | Premièrement, le Comité d’éthique n'a pas voulu « réinventer la roue ».                              |
# | 115 | Ombudsman and Child and Youth Advocate Report                                                        | Rapport de l'ombudsman et du défenseur des enfants et de la jeunesse                                 |
# | 116 | It is true that he never got to fight, but not for lack of fighting spirit.                          | Il est vrai qu´il n´a jamais été au front, mais cela ne l´a jamais empêché d´être un battant.        |
# | 117 | New Frontiers Program:                                                                               | Programme Nouvelles frontières :                                                                     |
# | 118 | Memory, War, and the Search for a Family’s Past David MacFarlane New York, NY:                       | Memory, War, and the Search for a Family’s Past David MacFarlane New York (N.                        |
# | 119 | The other tariffs will be the subject of decisions to be rendered in 1994-1995.                      | Les autres tarifs feront l&objet de décisions qui seront rendues en 1994-1995.                       |
# | 120 | agencies, Crown corporations and other non-federal organizations; specialized                        | compétences) de la Loi de crédits n o 2 pour 2007-2008 et pour prévoir un montant                    |
# | 121 | After the Second World War, Canadian railways began to adopt diesel power.                           | Après la Deuxième Guerre mondiale, les sociétés canadiennes de chemins de fer ont adopté le diesel.  |
# | 122 | United States-Canada Air Quality Agreement, Ozone Annex                                              | Annexe sur l'ozone de l'Accord Canada-États-Unis sur la qualité de l'air                             |
# | 123 | Amendment by Dorette Corbey Amendment 123 Article 4, paragraph 2 a (new) 2a.                         | Amendement déposé par Dorette Corbey Amendement 123 Article 4, paragraphe 2 a (nouveau) 2bis.        |
# | 124 | An audit determines that the supplies were, in fact, taxable at 15%.                                 | Une vérification détermine que les fournitures étaient, en fait, taxables à 15%.                     |
# | 125 | SATURN SCALE SYSTEMS INC.Mississauga, OntarioCertificate number:                                     | SATURN SCALE SYSTEMS INC.Mississauga (Ontario)Numéro de certificat :                                 |
# | 126 | Mr. Durand says Cuba will be a "tremendously difﬁcult" issue for the OAS.                            | Il y a aussi risque de désaccord au sujet de Cuba, qui sera d’actualité après l’ère Fidel Castro.    |
# | 127 | Experience: • Significant experience in fish habitat management and environmental assessment         | • Expérience appréciable de la gestion de l’habitat du poisson et de l’évaluation environnementale   |
# | 128 | Period covered by the notification 1994 - now.                                                       | Période sur laquelle porte la notification De 1994 à ce jour.                                        |
# | 129 | Lead content in gasoline lowered                                                                     | Diminution de la teneur en plomb dans l’essence                                                      |
# | 130 | The bureau has recently initiated studies into the non-auditory effects of noise exposure.           | Le bureau vient de lancer des études sur les effets non auditifs de l'exposition aux bruits.         |
# | 131 | The negative sign of the lost wage coeffi-                                                           | Le nouveau salaire prévu est ensuite pris                                                            |
# | 132 | "Stanley Park belongs to all Canadians."                                                             | Le parc Stanley appartient à tous les Canadiens.                                                     |
# | 133 | Chlamydia+ Gonococcus+ Both+ Both-                                                                   | Chlamydia+ Gonococcus+ Les deux+ Les deux-                                                           |
# | 134 | A Strategic Business Plan was developed to provide financial sustainability for the Centre.          | On a élaboré un plan d'activités stratégique pour assurer la viabilité financière du Centre.         |
# | 135 | • increased assisted childbirth: from 37% in 2001 to 65% in 2004; and                                | • augmentation de l’aide aux accouchements : 37 % en 2001; 65 % en 2004                              |
# | 136 | AP HA (1995) Stand ard m ethod s for the examination o f water an d wastewater.                      | APHA (1995) Standard methods for the examination of water and wastewater.                            |
# | 137 | A regulatory amendment was required to provide for a framework specific to NHPs.                     | Comme pour tout cadre réglementaire, une hausse des coûts est anticipée à court terme.               |
# | 138 | There are two secondary institutional forms not listed in the FAA:                                   | Il y a deux types d'institutions secondaires qui ne figurent pas dans la LGFP :                      |
# | 139 | It is estimated that the territory receives about €15 million a year from these various activities.  | On estime que ces activités rapportent environ 15 millions d'euros par an au territoire.             |
# | 140 | 1,3-bis (2-chloroethylthio) -n-propane (CAS 6390510-2); 6.                                           | 1,3-bis(2-Chloroéthylthio)-n-propane(CAS 63905-10-2); 6.                                             |
# | 141 | These projects will also have a significant spill-over effect for schools.                           | Ces projets auront également des retombées importantes au niveau scolaire.                           |
# | 142 | Tax Info Sheets                                                                                      | Feuilles de renseignements sur l'impôt                                                               |
# | 143 | • DEPRÉ Claire Assistant to the Director-General                                                     | • DEPRÉ Claire Assistant du directeur général                                                        |
# | 144 | 2002/09/23 - Municipality of Baker Lake - "Hard Copy Document"Description:                           | 2002/09/23 - Municipality of Baker Lake - "Version imprimée"Description:                             |
# | 145 | Canadian Education Research and Information System (CERIS).                                          | Une autre option des Initiatives liées à l’acquisition du savoir serait de                           |
# | 146 | This report provides a summary of the results of that meeting.                                       | Les résultats de cette réunion sont résumés dans le présent rapport.                                 |
# | 147 | Most often, however, the language of the principal audio feed is English.                            | Cependant, le plus souvent la langue de la principale source audio est l'anglais.                    |
# | 148 | Non-discrimination (Disability)                                                                      | Non-discrimination (Handicap)                                                                        |
# | 149 | We will take on board position of Parliament and will take it seriously," he said.                   | Le compromis exclut de manière totalement explicite les acquis sociaux et le droit du travail.       |
# | 150 | 209 LUCILLE AVE LAFAYETTE, LA 70502 Telephone: (318) 2611870 Details:                                | 209 LUCILLE AVE LAFAYETTE, LA 70502 Téléphone : (318) 2611870 Genre d'entreprise :                   |
# | 151 | WHAT IS THE SCHOLARSHIP PROGRAM FOR WOMEN?                                                           | CE QUE SONT LES BOURSES D’ÉTUDES À L'INTENTION DES FEMMES ?                                          |
# | 152 | This will lead to the creation of a national databank of stars.                                      | De là pourrait être constituée une banque nationale de données à cet effet.                          |
# | 153 | With our two salaries and only one house to pay for, life was good.                                  | Avec deux salaires et une seule maison à payer, on vivait bien.                                      |
# | 154 | Web content checklist a.                                                                             | Liste de contrôle du contenu Web a) Connaître ses lecteurs                                           |
# | 155 | • relevant health professions with subject-matter expertise;                                         | • des professions de la santé pertinentes ayant une expertise technique du domaine;                  |
# | 156 | Tariff Notice 24 - Compensation for Traffic Termination                                              | Avis de modification tarifaire 24 - Compensation pour la terminaison du trafic                       |
# | 157 | Measures have already been taken.                                                                    | Des mesures ont par ailleurs déjà été prises en ce sens.                                             |
# | 158 | Take a look at NRC materials and manufacturing R&D in action.                                        | Examinez la R-D du CNRC dans le domaine des matériaux et de la fabrication.                          |
# | 159 | Since its inception in 1996, more than 523,000 young Canadians have taken part in Future Links.      | Le bureau national situé à Acton, Ontario supervise neuf bureaux régionaux à travers le pays.        |
# | 160 | Eocene, Fagus, fossil, foliage, fruits, British Columbia.                                            | Éocène, Fagus, fossile, feuillage, fruits, Colombie-Britannique.                                     |
# | 161 | PROFESSOR JIANG JING Reference Number:                                                               | PROFESSOR JIANG JING Numéro de référence:                                                            |
# | 162 | The HPFB ADM’s decision is one of the following:                                                     | La décision du SMA de la DGPSA est l’une des décisions suivantes :                                   |
# | 163 | For example, a 60% probability of snow today does not mean that it will snow during 60% of the day.  | 100 de la journée. Toutefois, ce pourcentage signifie qu’il y a 60 p.                                |
# | 164 | DPR 2003-2004Department of Justice Canada                                                            | RMR 2003 - 2004Ministère de la Justice Canada                                                        |
# | 165 | It might be wise to make inquiries before organizing any activities.                                 | Il vaut mieux vous informer avant d'organiser les activités.                                         |
# | 166 | Unit Startup (year 1) Total x6 Can-SPORES Total x6 Can-SPORES Personnel 1.0 EFT nurse $75,000        | Démarrage Unité (année 1) Total x6 PSRE Can Total x6 PSRE Can Personnel 1,0 EPT infirmière $75 000   |
# | 167 | (b) The RSP cannot provide for the payment of any benefit after maturity except:                     | b) le versement d'une prestation après l'échéance, sauf                                              |
# | 168 | • Increasing climatic variability: rainfall, hurricane intensity                                     | • Variation climatique accrue: pluviométrie, intensité des ouragans                                  |
# | 169 | Afghanistan under the Taliban was such a State.                                                      | C'était le cas de l'Afghanistan sous le régime des Talibans.                                         |
# | 170 | Our doors are always open to their parliamentarians, many of whom are here this afternoon.           | Le fait de le présenter de cette façon est vraisemblablement un outil pour la mener.                 |
# | 171 | In each year, new counting points were used to achieve more representative coverage of the island.   | La proportion estimée de Sternes pierregarins a augmenté de 5 ou 6 p.                                |
# | 172 | The majority of employed Canadians do not rely on social support networks for help.                  | La majorité des employés canadiens ne comptent pas sur l'aide de réseaux de soutien social.          |
# | 173 | Despite being approved by the DTI and the DOST, the IRR is voluntary.                                | Bien qu'ils aient été approuvés par le DTI et le DOST, les IRR ont un caractère volontaire.          |
# | 174 | I cannot resist citing a part of his speech:                                                         | Je ne puis m'empêcher de vous citer un passage de son discours:                                      |
# | 175 | It approves an annual report to stakeholders and central agencies.                                   | Il approuve le rapport annuel présenté aux parties intéressées et aux organismes centraux.           |
# | 176 | THE 1996 INTERGOVERNMENTAL CONFERENCE..                                                              | En ce qui concerne la réforme institutionnelle, le gouvernement danois souligne les points suivants: |
# | 177 | It does not extend to donations in kind made to registered charities.                                | Elle ne s'étend pas aux dons en nature faits à des organismes de bienfaisance enregistrés.           |
# | 178 | In situ conservation and intellectual property rights français - Español                             | In situ conservation and intellectual property rights English - Español                              |
# | 179 | • Improved management practices                                                                      | • Meilleures pratiques de gestion                                                                    |
# | 180 | THE PRESIDENT (Translation). – Thank you.                                                            | Cela explique que, jusqu’à présent, l’Etat ait peu eu à s’occuper du sujet.                          |
# | 181 | As a student of agriculture, you'll notice how important a solid business plan is.                   | Comme vous étudiez en agriculture, vous connaissez l’importance d’un plan d’affaires solide.         |
# | 182 | 8629 Fox, Breeding, Reynards                                                                         | 8629 Renard, de reproduction, mâle                                                                   |
# | 183 | • The vendor was obligated to report the status of all GFE on a quarterly basis.                     | • Le fournisseur était tenu de présenter des rapports trimestriels sur l’état de tout l’EFG.         |
# | 184 | Harmonisation:                                                                                       | Harmonisation :                                                                                      |
# | 185 | • How long do we need to keep receipts for?                                                          | • Pendant combien de temps faut-il conserver les reçus ?                                             |
# | 186 | United States Department of Health and Human Services.                                               | U.S. Department of Health and Human Services.                                                        |
# | 187 | Vacant houses which were unfit for habitation were not to be recorded.                               | S'il y avait des maisons vacantes inhabitables, elles n'étaient pas inscrites.                       |
# | 188 | The ninth Social Dialogue Summit was held in Genval (Belgium) on 28 November (4).                    | Le 28 novembre s'est tenu à Genval (Belgique) le neuvième sommet du dialogue social (4).             |
# | 189 | Deliverables and Time Frame Deliverables Start Date Completion Date 1.                               | Résultats prévus et échéancier Résultats prévus Début Fin 1.                                         |
# | 190 | - Small Business Corporate Income Tax Rate Ö                                                         | - Taux d'impôt des sociétés - petites entreprises Ö                                                  |
# | 191 | Bilateral Emergency Measures for Textile and Apparel Goods Imported from a NAFTA Country             | (5) Le présent article cesse d'avoir effet le 31 décembre 2002.                                      |
# | 192 | In a limited early investigation reported by Blood et al.                                            | Dans une ancienne étude limitée rapportée par Blood et al.                                           |
# | 193 | Request for authorization:                                                                           | Demande d’autorisation :                                                                             |
# | 194 | In 2001 there were "mini-riots" in Bradford, and then in Oldham and Burnley.                         | En 2001, des « mini-émeutes » se sont déroulées à Bradford, puis à Oldham, Burnley.                  |
# | 195 | If consent denied, leave route as Settlement Land.                                                   | Si le consentement est refusé, laisser la voie comme une terre visée par le règlement.               |
# | 196 | Bank Al-Maghrib, Ministry of Finance and Privatisation, IMF, World Bank, EIU.                        | Including Hassan II Fund.                                                                            |
# | 197 | However, it determined this is not part of CIHR's mandate.                                           | Toutefois, il a déterminé que cela n'entrait pas dans le mandat des IRSC.                            |
# | 198 | • Voluntary Sector IAB members                                                                       | • les membres des CCI relevant du secteur bénévole et communautaire;                                 |
# | 199 | Informants who mentioned these decisions viewed them positively.                                     | Elles sont considérées positivement par les informateurs qui les ont évoquées.                       |
# +-----+------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------+

# %%
# !pip install evaluate
# !pip install unbabel-comet
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.2
# Collecting unbabel-comet
#   Downloading unbabel_comet-2.2.2-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 3.1 MB/s eta 0:00:00
# Collecting entmax<2.0,>=1.1 (from unbabel-comet)
#   Downloading entmax-1.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (0.23.0)
# Collecting jsonargparse==3.13.1 (from unbabel-comet)
#   Downloading jsonargparse-3.13.1-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (1.25.2)
# Requirement already satisfied: pandas>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (2.0.3)
# Collecting protobuf<5.0.0,>=4.24.4 (from unbabel-comet)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 12.0 MB/s eta 0:00:00
# Collecting pytorch-lightning<3.0.0,>=2.0.0 (from unbabel-comet)
#   Downloading pytorch_lightning-2.2.4-py3-none-any.whl (802 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.2/802.2 kB 15.4 MB/s eta 0:00:00
# Collecting sacrebleu<3.0.0,>=2.0.0 (from unbabel-comet)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0.0,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (1.11.4)
# Requirement already satisfied: sentencepiece<0.2.0,>=0.1.96 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (0.1.99)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (2.2.1+cu121)
# Collecting torchmetrics<0.11.0,>=0.10.2 (from unbabel-comet)
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0,>=4.17 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (4.40.2)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from jsonargparse==3.13.1->unbabel-comet) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.1->unbabel-comet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.1->unbabel-comet) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.1->unbabel-comet) (2024.1)
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Collecting portalocker (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (0.9.0)
# Collecting colorama (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (4.9.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->unbabel-comet) (12.4.127)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0,>=4.17->unbabel-comet) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0,>=4.17->unbabel-comet) (0.4.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.1->unbabel-comet) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->unbabel-comet) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->unbabel-comet) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.0.3)
# Installing collected packages: protobuf, portalocker, lightning-utilities, jsonargparse, colorama, sacrebleu, torchmetrics, entmax, pytorch-lightning, unbabel-comet
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.3 which is incompatible.
# Successfully installed colorama-0.4.6 entmax-1.3 jsonargparse-3.13.1 lightning-utilities-0.11.2 portalocker-2.8.2 protobuf-4.25.3 pytorch-lightning-2.2.4 sacrebleu-2.4.2 torchmetrics-0.10.3 unbabel-comet-2.2.2

# %%
from nltk.translate.bleu_score import sentence_bleu
from evaluate import load
from nltk.translate.bleu_score import corpus_bleu
import numpy as np
import pandas as pd
comet_metric = load('comet')
# Out:
# Downloading builder script:   0%|          | 0.00/6.97k [00:00<?, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# hparams.yaml:   0%|          | 0.00/567 [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/9.69k [00:00<?, ?B/s]
# model.ckpt:   0%|          | 0.00/2.32G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.53k [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.8.3.post1 to v2.2.4. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/huggingface/hub/models--Unbabel--wmt22-comet-da/snapshots/371e9839ca4e213dde891b066cf3080f75ec7e72/checkpoints/model.ckpt`
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/saving.py:188: Found keys that are not in the model state dict but in the checkpoint: ['encoder.model.embeddings.position_ids']

# %% [markdown]
# ### Calculating BLUE and COMET for model 100k data

# %%
source = test_df['en'].tolist()
hypothesis = [translate_text(text, model_100k, tokenizer) for text in source]
reference = test_df['fr'].tolist()

#COMET score
comet_results = comet_metric.compute(predictions=hypothesis, references=reference, sources=source)

#BLUE score
def calculate_bleu_score(reference, candidate):
    return corpus_bleu([[ref] for ref in reference], candidate)

bleu_scores = [calculate_bleu_score([ref], [hyp]) for ref, hyp in zip(reference, hypothesis)]

average_bleu_score = sum(bleu_scores) / len(bleu_scores)

average_comet_score = np.mean(comet_results["scores"])

print("Average BLUE score", average_bleu_score)
print("Average COMET score", average_comet_score)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA L4') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Average BLUE score 0.42398479938748995
# Average COMET score 0.6742683421468261
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %% [markdown]
# ### Calculating BLUE and COMET for model 200k data

# %%
source = test_df['en'].tolist()
hypothesis = [translate_text(text, model_200k, tokenizer) for text in source]
reference = test_df['fr'].tolist()

#COMET score
comet_results = comet_metric.compute(predictions=hypothesis, references=reference, sources=source)

#BLUE score
def calculate_bleu_score(reference, candidate):
    return corpus_bleu([[ref] for ref in reference], candidate)

bleu_scores = [calculate_bleu_score([ref], [hyp]) for ref, hyp in zip(reference, hypothesis)]

average_bleu_score = sum(bleu_scores) / len(bleu_scores)

average_comet_score = np.mean(comet_results["scores"])

print("Average BLUE score", average_bleu_score)
print("Average COMET score", average_comet_score)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Average BLUE score 0.44105867833948786
# Average COMET score 0.6934882266011404
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


data = {
    'Model': ['mT5 Full fine-tuning', 'mT5 QLoRa', 'mT5 Prompt-tuning', 'Llama 2 QLoRa\nUnsloth Library'],
    'BLEU Score': [44.11, 26.49, 42.39, 52.05],
    'COMET Score': [69.35, 51.7, 63.89, 76.86],
}

df = pd.DataFrame(data)
df_melted = df.melt(id_vars='Model', value_vars=['BLEU Score', 'COMET Score'], var_name='Metric', value_name='Score')
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Score', hue='Metric', data=df_melted, palette={'BLEU Score': 'blue', 'COMET Score': 'red'})
plt.xlabel('Machine Translation Models')
plt.ylabel('Scores')
plt.title('Comparison of BLEU and COMET Scores across different Models')
plt.show()

# %%
pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.11.0)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
from docx import Document

def translate_text(text, model, tokenizer):
    inputs = tokenizer.encode("translate English to French: " + text, return_tensors="pt")
    outputs = model.generate(inputs, max_length=64, num_beams=4, early_stopping=True)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return translated_text

doc = Document()
for i, (index, row) in enumerate(test_df.iterrows(), 1):
    english_sentence = row['en']
    target_french_sentence = row['fr']
    translated_french_sentence = translate_text(english_sentence, model_200k, tokenizer)
    doc.add_paragraph(f"{i}) English Sentence: {english_sentence}")
    doc.add_paragraph(f"   Translated French Sentence: {translated_french_sentence}")
    doc.add_paragraph(f"   Target French Sentence: {target_french_sentence}")
    doc.add_paragraph()

doc.save("translated_sentences.docx")
